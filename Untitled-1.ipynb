# %%
#import PyPDF4
import os
import fnmatch
import fitz
import re
from datetime import datetime

# import pandas as pd
import pandas as pd

# %%
#read all PDF files
def find_all_files(path):
    all_files = []

    for root, dirs, files in os.walk(path):
        for file in fnmatch.filter(files,'*.pdf'):
#
            full_path=os.path.abspath(file)
            all_files.append(os.path.join(root, file))
    return all_files

# %%
#Specify the path of the folder to look the PDFs of the bills
initial_folder='.'
pdf_files=find_all_files(initial_folder)
# List of every page's text.
# # The index will correspond to the pdf number.
pdf_text = []
for file in pdf_files:
   doc = fitz.open(file)
   text = ""
   for page in doc:
      text+=page.get_text()
   pdf_text.append(text)

# %%
#Function to read the amount to pay. It always has the symbol * before the amount (in Euros), e.g., *195,00 
def find_amount(text,amount):
    match=re.search(r'\*\d{1,},\d{1,}',text)
    #add exception when there is a refund and no amount is written
    try:
        #print(match.group(0))
        value=match.group(0)[1:]
        value=value[:-1]
        value=value.replace(',', '.')
        amount.append(float(value))
    except:
        print('Add zero if the bill is negative')
        amount.append(0)
    else:
         pass
    return amount

# %%
#Function to read the consumption of kWh 
def find_consumption(text,amount):
    match=re.search(r"\d{1,} kWh|\d.\d{1,} kWh",text)
    #print(match)
    #add exception when there is a refund and no amount is written
    # ATTENTION::: FIX The 
    try:
        #print(match.group(0))
        value=match.group(0).split()
        amount.append(float(value[0]))
    except:
        print('Add zero if there is no consumption')
        amount.append(0)

    return amount

# %%
#Function to read the date of consumption 
def find_date(text,begin,end):
    match=re.findall(r"\d{2}/\d{2}/\d{4}",text)
    #print(match)
    #25/06/2022
    #add exception when there is a refund and no amount is written
    # try:
    #     print(match.group(0))
    #     #value=match.group(0).split()
    #     #amount.append(value[0])
    # except:
    #     print('No data for period of consumption available')
    #     amount.append(0)
    #amount.append(match[1:3])
    dts=[]
    for dt in match:

        date_time_obj = datetime.strptime(dt,'%d/%m/%Y')
        #print(date_time_obj)
        dts.append(date_time_obj.date())
        #print(dts)
    #check date because the format of date changes after some bills
    if (dts[1]<dts[2] and dts[2]<dts[3]):
        begin.append(dts[1])
        end.append(dts[2])
    else:
        begin.append(dts[2])
        end.append(dts[3])       
    return begin,end

# %%
# # date in yyyy/mm/dd format
# d1 = dt.datetime(2018, 5, 3)
# d2 = dt.datetime(2018, 6, 1)
  
# # Comparing the dates will return
# # either True or False
# print("d1 is greater than d2 : ", d1 > d2)
# print("d1 is less than d2 : ", d1 < d2)
# print("d1 is not equal to d2 : ", d1 != d2)
from datetime import datetime
date_time_obj = datetime.strptime('30/06/2016','%d/%m/%Y')
date_time_obj_2 = datetime.strptime('20/06/2016','%d/%m/%Y')

# %%
print(date_time_obj.date()-date_time_obj_2.date())
# Out:
# 10 days, 0:00:00

# %%
#Extract the info that we want
#Katanalosi, euro and date
monthly_pay=[]
consumption=[]
begin_consumption=[]
end_consumption=[]

#Iterate over the extracted PDF text.
for f in pdf_text:
    #First, find what do we pay each month.
    find_amount(f,monthly_pay)
    #Next, find the date of consumption.
    find_date(f,begin_consumption,end_consumption)
    #Finally, find the consumption of kWh.
    find_consumption(f,consumption)
# Out:
# Add zero if there is no consumption
# Add zero if there is no consumption
# Add zero if there is no consumption
# Add zero if there is no consumption
# Add zero if there is no consumption
# Add zero if there is no consumption
# Add zero if there is no consumption
# Add zero if the bill is negative

# %%
consumption
# Out:
# [1274.0,
#  0,
#  1384.0,
#  0,
#  1312.0,
#  0,
#  1194.0,
#  0,
#  1458.0,
#  0,
#  1243.0,
#  0,
#  1204.0,
#  0,
#  1316.0,
#  508.0,
#  1108.0,
#  519.0,
#  1059.0,
#  561.0,
#  1347.0,
#  558.0,
#  1145.0,
#  525.0,
#  1183.0,
#  640.0,
#  1273.0,
#  543.0,
#  335.0,
#  1207.0,
#  287.0,
#  277.0,
#  315.0,
#  1045.0,
#  302.0,
#  339.0,
#  318.0,
#  1614.0,
#  331.0,
#  292.0,
#  312.0,
#  1226.0,
#  267.0,
#  252.0,
#  287.0,
#  1082.0,
#  269.0,
#  440.0,
#  401.0,
#  1.387]

# %%
# Calling DataFrame constructor after zipping
# both lists, with columns specified
df = pd.DataFrame(list(zip(begin_consumption, end_consumption,consumption,monthly_pay)),
               columns =['Start of consumption', 'End of consumption','Consumption [kWh]','Bill [EURO]'])

# %%
df
# Out:
#    Start of consumption End of consumption  Consumption [kWh]  Bill [EURO]
# 0            2016-02-22         2016-06-22           1274.000        195.0
# 1            2016-06-23         2016-08-22              0.000        154.0
# 2            2016-06-23         2016-10-20           1384.000        188.0
# 3            2016-10-21         2016-12-20              0.000        123.0
# 4            2016-10-21         2017-02-19           1312.000        186.0
# 5            2017-02-20         2017-04-19              0.000        114.0
# 6            2017-02-20         2017-06-22           1194.000        174.0
# 7            2017-06-23         2017-08-22              0.000        127.0
# 8            2017-06-23         2017-10-23           1458.000        209.0
# 9            2017-10-24         2017-12-18              0.000        134.0
# 10           2017-10-24         2018-02-20           1243.000        181.0
# 11           2018-02-21         2018-04-19              0.000        104.0
# 12           2018-02-21         2018-06-21           1204.000        181.0
# 13           2018-06-22         2018-08-22              0.000        134.0
# 14           2018-06-22         2018-10-24           1316.000        174.0
# 15           2018-10-25         2018-12-18            508.000        111.0
# 16           2018-10-25         2019-02-18           1108.000        156.0
# 17           2019-02-19         2019-04-16            519.000        118.0
# 18           2019-02-19         2019-06-20           1059.000        144.0
# 19           2019-06-21         2019-08-20            561.000        130.0
# 20           2019-06-21         2019-10-20           1347.000        178.0
# 21           2019-10-21         2019-12-18            558.000        136.0
# 22           2019-10-21         2020-02-20           1145.000        147.0
# 23           2020-02-21         2020-04-22            525.000        126.0
# 24           2020-02-21         2020-06-23           1183.000        162.0
# 25           2020-06-24         2020-08-20            640.000        147.0
# 26           2020-06-24         2020-10-21           1273.000        151.0
# 27           2020-10-22         2021-02-23            543.000        121.0
# 28           2020-12-22         2021-02-23            335.000          0.0
# 29           2020-10-22         2021-06-23           1207.000         57.0
# 30           2021-02-23         2021-06-23            287.000         65.0
# 31           2021-03-25         2021-06-23            277.000         69.0
# 32           2021-04-23         2021-06-23            315.000         78.0
# 33           2021-02-23         2021-10-22           1045.000         53.0
# 34           2021-06-23         2021-10-22            302.000         74.0
# 35           2021-07-24         2021-10-22            339.000        120.0
# 36           2021-08-25         2021-10-22            318.000         82.0
# 37           2021-06-23         2022-02-22           1614.000        160.0
# 38           2021-10-22         2022-02-22            331.000         80.0
# 39           2021-11-25         2021-12-24            292.000        100.0
# 40           2021-12-25         2022-01-25            312.000         83.0
# 41           2021-10-22         2022-02-23           1226.000         88.0
# 42           2022-02-24         2022-03-23            267.000         65.0
# 43           2022-03-24         2022-04-21            252.000         45.0
# 44           2022-04-22         2022-05-24            287.000         79.0
# 45           2022-02-24         2022-06-24           1082.000         81.0
# 46           2022-06-25         2022-07-22            269.000         66.0
# 47           2022-07-23         2022-08-24            440.000        104.0
# 48           2022-08-25         2022-09-23            401.000         96.0
# 49           2022-06-25         2022-10-24              1.387         83.0

# %%
# Bar chart 
# plt.bar(df['Start of consumption'], df['Bill [EURO]'])
 
# plt.title("Bar Chart")
 
# # Setting the X and Y labels
# plt.xlabel('Date')
# plt.ylabel('Bill [EURO]')
 
# # Adding the legends
# plt.show()

# Scatter plot with day against tip
plt.plot(df['Bill [EURO]'])
 
# Adding Title to the Plot
plt.title("Scatter Plot")
 
# Setting the X and Y labels
plt.xlabel('Day')
plt.ylabel('Bill [EURO]')
 
plt.show()

# %%
import matplotlib.pyplot as plt

# %%
begin_consumption
# Out:
# [datetime.date(2016, 2, 22),
#  datetime.date(2016, 6, 23),
#  datetime.date(2016, 6, 23),
#  datetime.date(2016, 10, 21),
#  datetime.date(2016, 10, 21),
#  datetime.date(2017, 2, 20),
#  datetime.date(2017, 2, 20),
#  datetime.date(2017, 6, 23),
#  datetime.date(2017, 6, 23),
#  datetime.date(2017, 10, 24),
#  datetime.date(2017, 10, 24),
#  datetime.date(2018, 2, 21),
#  datetime.date(2018, 2, 21),
#  datetime.date(2018, 6, 22),
#  datetime.date(2018, 6, 22),
#  datetime.date(2018, 10, 25),
#  datetime.date(2018, 10, 25),
#  datetime.date(2019, 2, 19),
#  datetime.date(2019, 2, 19),
#  datetime.date(2019, 6, 21),
#  datetime.date(2019, 6, 21),
#  datetime.date(2019, 10, 21),
#  datetime.date(2019, 10, 21),
#  datetime.date(2020, 2, 21),
#  datetime.date(2020, 2, 21),
#  datetime.date(2020, 6, 24),
#  datetime.date(2020, 6, 24),
#  datetime.date(2020, 10, 22),
#  datetime.date(2020, 12, 22),
#  datetime.date(2020, 10, 22),
#  datetime.date(2021, 2, 23),
#  datetime.date(2021, 3, 25),
#  datetime.date(2021, 4, 23),
#  datetime.date(2021, 2, 23),
#  datetime.date(2021, 6, 23),
#  datetime.date(2021, 7, 24),
#  datetime.date(2021, 8, 25),
#  datetime.date(2021, 6, 23),
#  datetime.date(2021, 10, 22),
#  datetime.date(2021, 11, 25),
#  datetime.date(2021, 12, 25),
#  datetime.date(2021, 10, 22),
#  datetime.date(2022, 2, 24),
#  datetime.date(2022, 3, 24),
#  datetime.date(2022, 4, 22),
#  datetime.date(2022, 2, 24),
#  datetime.date(2022, 6, 25),
#  datetime.date(2022, 7, 23),
#  datetime.date(2022, 8, 25),
#  datetime.date(2022, 6, 25)]

# %%
(end_consumption)
# Out:
# [datetime.date(2016, 6, 22),
#  datetime.date(2016, 8, 22),
#  datetime.date(2016, 10, 20),
#  datetime.date(2016, 12, 20),
#  datetime.date(2017, 2, 19),
#  datetime.date(2017, 4, 19),
#  datetime.date(2017, 6, 22),
#  datetime.date(2017, 8, 22),
#  datetime.date(2017, 10, 23),
#  datetime.date(2017, 12, 18),
#  datetime.date(2018, 2, 20),
#  datetime.date(2018, 4, 19),
#  datetime.date(2018, 6, 21),
#  datetime.date(2018, 8, 22),
#  datetime.date(2018, 10, 24),
#  datetime.date(2018, 12, 18),
#  datetime.date(2019, 2, 18),
#  datetime.date(2019, 4, 16),
#  datetime.date(2019, 6, 20),
#  datetime.date(2019, 8, 20),
#  datetime.date(2019, 10, 20),
#  datetime.date(2019, 12, 18),
#  datetime.date(2020, 2, 20),
#  datetime.date(2020, 4, 22),
#  datetime.date(2020, 6, 23),
#  datetime.date(2020, 8, 20),
#  datetime.date(2020, 10, 21),
#  datetime.date(2021, 2, 23),
#  datetime.date(2021, 2, 23),
#  datetime.date(2021, 6, 23),
#  datetime.date(2021, 6, 23),
#  datetime.date(2021, 6, 23),
#  datetime.date(2021, 6, 23),
#  datetime.date(2021, 10, 22),
#  datetime.date(2021, 10, 22),
#  datetime.date(2021, 10, 22),
#  datetime.date(2021, 10, 22),
#  datetime.date(2022, 2, 22),
#  datetime.date(2022, 2, 22),
#  datetime.date(2021, 12, 24),
#  datetime.date(2022, 1, 25),
#  datetime.date(2022, 2, 23),
#  datetime.date(2022, 3, 23),
#  datetime.date(2022, 4, 21),
#  datetime.date(2022, 5, 24),
#  datetime.date(2022, 6, 24),
#  datetime.date(2022, 7, 22),
#  datetime.date(2022, 8, 24),
#  datetime.date(2022, 9, 23),
#  datetime.date(2022, 10, 24)]

# %%
pdf_files
# Out:
# ['./440611581014_01012011_31102022/440611581014_20160628_250468793_1.pdf',
#  './440611581014_01012011_31102022/440611581014_20160824_257591892_1.pdf',
#  './440611581014_01012011_31102022/440611581014_20161027_265695854_1.pdf',
#  './440611581014_01012011_31102022/440611581014_20161222_272576882_1.pdf',
#  './440611581014_01012011_31102022/440611581014_20170223_280360022_1.pdf',
#  './440611581014_01012011_31102022/440611581014_20170421_287254821_1.pdf',
#  './440611581014_01012011_31102022/440611581014_20170628_295352181_1.pdf',
#  './440611581014_01012011_31102022/440611581014_20170824_302410415_1.pdf',
#  './440611581014_01012011_31102022/440611581014_20171027_310215734_1.pdf',
#  './440611581014_01012011_31102022/440611581014_20171220_317198697_1.pdf',
#  './440611581014_01012011_31102022/440611581014_20180226_324951096_1.pdf',
#  './440611581014_01012011_31102022/440611581014_20180423_331493183_1.pdf',
#  './440611581014_01012011_31102022/440611581014_20180627_339285410_1.pdf',
#  './440611581014_01012011_31102022/440611581014_20180825_346142177_1.pdf',
#  './440611581014_01012011_31102022/440611581014_20181029_353917824_1.pdf',
#  './440611581014_01012011_31102022/440611581014_20181220_360630236_1.pdf',
#  './440611581014_01012011_31102022/440611581014_20190222_368076659_1.pdf',
#  './440611581014_01012011_31102022/440611581014_20190418_374634408_1.pdf',
#  './440611581014_01012011_31102022/440611581014_20190626_382096034_1.pdf',
#  './440611581014_01012011_31102022/440611581014_20190822_388723071_1.pdf',
#  './440611581014_01012011_31102022/440611581014_20191025_395992772_1.pdf',
#  './440611581014_01012011_31102022/440611581014_20191220_402509558_1.pdf',
#  './440611581014_01012011_31102022/440611581014_20200226_409482646_1.pdf',
#  './440611581014_01012011_31102022/440611581014_20200424_415780802_1.pdf',
#  './440611581014_01012011_31102022/440611581014_20200629_422714845_1.pdf',
#  './440611581014_01012011_31102022/440611581014_20200824_429705590_1.pdf',
#  './440611581014_01012011_31102022/440611581014_20201026_436493296_1.pdf',
#  './440611581014_01012011_31102022/440611581014_20201223_442748658_1.pdf',
#  './440611581014_01012011_31102022/440611581014_20210127_446141843_1.pdf',
#  './440611581014_01012011_31102022/440611581014_20210225_449382205_1.pdf',
#  './440611581014_01012011_31102022/440611581014_20210326_452453661_1.pdf',
#  './440611581014_01012011_31102022/440611581014_20210423_455569390_1.pdf',
#  './440611581014_01012011_31102022/440611581014_20210526_458763449_1.pdf',
#  './440611581014_01012011_31102022/440611581014_20210625_461977300_1.pdf',
#  './440611581014_01012011_31102022/440611581014_20210726_465062205_1.pdf',
#  './440611581014_01012011_31102022/440611581014_20210825_468155293_1.pdf',
#  './440611581014_01012011_31102022/440611581014_20210924_471303895_1.pdf',
#  './440611581014_01012011_31102022/440611581014_20211026_474506475_1.pdf',
#  './440611581014_01012011_31102022/440611581014_20211125_477507407_1.pdf',
#  './440611581014_01012011_31102022/440611581014_20211227_481115527_1.pdf',
#  './440611581014_01012011_31102022/440611581014_20220126_484158219_1.pdf',
#  './440611581014_01012011_31102022/440611581014_20220228_487635842_1.pdf',
#  './440611581014_01012011_31102022/440611581014_20220324_490368922_1.pdf',
#  './440611581014_01012011_31102022/440611581014_20220428_493539333_1.pdf',
#  './440611581014_01012011_31102022/440611581014_20220525_496652205_1.pdf',
#  './440611581014_01012011_31102022/440611581014_20220628_499983738_1.pdf',
#  './440611581014_01012011_31102022/440611581014_20220725_502899171_1.pdf',
#  './440611581014_01012011_31102022/440611581014_20220825_505896753_1.pdf',
#  './440611581014_01012011_31102022/440611581014_20220926_509098880_1.pdf',
#  './440611581014_01012011_31102022/440611581014_20221026_512288216_1.pdf']

# %%
pdf_text[-1]
# Out:
# "  \n  \nΑΔΜΗΕ-ΔΕΔΔΗΕ ....:\n38,11\nΥΚΩ..............:\n9,57\nΕΤΜΕΑΡ...........:\n23,58\nΛΟΙΠΕΣ ΧΡΕΩΣΕΙΣ..:\n0,03\nΔΙΑΦΟΡΕΣ ΧΡΕΩΣΕΙΣ:\n3,87\nΔΗΜΟΣ............:\n27,66\nΕΡΤ .............:\n3,06\nΚΑΤΑΝΑΛΩΣΗ ......:\n1.387\n1\nΔΕΗ A.E.\nΧαλκοκονδύλη 30, 104 32 Αθήνα,\nΑ.Φ.Μ. 090000045, Δ.Ο.Υ. ΦΑΕ ΑΘΗΝΩΝ\ndei.gr\nΕΞΥΠΗΡΕΤΗΣΗ ΠΕΛΑΤΩΝ ΔΕΗ\nΕΞΥΠΗΡΕΤΗΣΗ ΔΕΔΔΗΕ\n��������\n000127908906\n�������������������������\n�������������������������\n�������������������������\n�������������������������\nΣκανάρετε\nγια άμεση εξόφληση\n800 900 1000 (ΔΩΡΕΑΝ)\nΚΑΤΑΣΤΗΜΑ ΛΑΡΙΣΑΣ\nΚΑΡΔΙΤΣΑΣ 99 & ΑΜΟΡΓΟΥ 413 35\n800 400 4000 (ΔΩΡΕΑΝ)\nΠληροφορίες | Βλάβες |\nΚαταμέτρηση\n013307\nΤΣΙΜΠΟΥΚΗΣ ΑΘΑΝΑΣΙΟΣΧΡΗΣΤΟΣ\n25ΗΣ ΜΑΡΤΙΟΥ 25\n412 21 ΛΑΡΙΣΑ\n10\nΚωδικός ηλεκτρονικής πληρωμής\nRF53907738000300005250337\n������������������������\n000000083,00  6\nΕκκαθαριστικός\nλογαριασμός\nΤιμολόγιο:\n myHome Enter N\nΔιεύθυνση ακινήτου:\n25ΗΣ ΜΑΡΤΙΟΥ 25\n412 21 ΛΑΡΙΣΑ\nΕπόμενη καταμέτρηση:\n21/02/2023\nΑριθμός παροχής\n4 40611581-01 1\nΧρεώσεις προμήθειας ΔΕΗ\n145 , 44€\nΡυθμιζόμενες χρεώσεις\n71 , 29€\nΈναντι Κατανάλωσης\n- 171 , 23€\nΔιάφορα - Δήμος - ΕΡΤ\n34 , 59€\nΦΠΑ\n2 , 91€\nΠροηγούμενο Ανεξόφλητο Ποσό\nΑγνοήστε το εάν έχει πληρωθεί\nΣυνολικό ποσό πληρωμής\n*83 , 00€\nΠΟΣΟ ΠΛΗΡΩΜΗΣ\n*83,00€\nΕΞΟΦΛΗΣΗ ΕΩΣ\n17/11/2022\nΗ κατανάλωσή σας\nΚατανάλωση Ηλεκτρικής Ενέργειας 1.387 kWh\nΠερίοδος Κατανάλωσης\n25/06/2022     -     24/10/2022\nΗμέρες\n122\nΗμ/νία Έκδοσης\n26/10/2022\nΑ/Α Λογαριασμού\n1310962402\nΣελίδα 1 από 2\n  299-2022\nEL-00013307\nΚλείστε τώρα ραντεβού, εύκολα & γρήγορα, σε ένα από τα επιλεγμένα καταστήματα, με ένα κλικ στο dei.gr\nΈχετε ενεργοποιήσει Σύμβαση για το προϊόν\nMyHomeEnter.\nΗ Σύμβαση λήγει 29/12/2022.\nΣας ενημερώνουμε για τη δυνατότητα ένταξης στο Κοινωνικό Οικιακό\nΤιμολόγιο (ΚΟΤ) μέσω της ιστοσελίδας της ΗΔΙΚΑ Α.Ε. (www.idika.gr).\nΥπενθυμίζουμε ότι το Τιμολόγιο Πολυτέκνων κατaργήθηκε και η\nσυγκεκριμένη κατηγορία εντάσσεται πλέον στο ΚΟΤ (ΦΕΚ 242/01.02.2018).\nΠληροφορίες στο 800 900 1000 (ΔΩΡΕΑΝ), στο dei.gr ή και στο www.idika.gr.\n  \n  \nΑΔΜΗΕ-ΔΕΔΔΗΕ ....:\n38,11\nΥΚΩ..............:\n9,57\nΕΤΜΕΑΡ...........:\n23,58\nΛΟΙΠΕΣ ΧΡΕΩΣΕΙΣ..:\n0,03\nΔΙΑΦΟΡΕΣ ΧΡΕΩΣΕΙΣ:\n3,87\nΔΗΜΟΣ............:\n27,66\nΕΡΤ .............:\n3,06\nΚΑΤΑΝΑΛΩΣΗ ......:\n1.387\n1\nΔΕΗ A.E.\nΧαλκοκονδύλη 30, 104 32 Αθήνα,\nΑ.Φ.Μ. 090000045, Δ.Ο.Υ. ΦΑΕ ΑΘΗΝΩΝ\ndei.gr\nΕΞΥΠΗΡΕΤΗΣΗ ΠΕΛΑΤΩΝ ΔΕΗ\nΕΞΥΠΗΡΕΤΗΣΗ ΔΕΔΔΗΕ\n��������\n000127908906\n�������������������������\n�������������������������\n�������������������������\n�������������������������\nΣκανάρετε\nγια άμεση εξόφληση\n800 900 1000 (ΔΩΡΕΑΝ)\nΚΑΤΑΣΤΗΜΑ ΛΑΡΙΣΑΣ\nΚΑΡΔΙΤΣΑΣ 99 & ΑΜΟΡΓΟΥ 413 35\n800 400 4000 (ΔΩΡΕΑΝ)\nΠληροφορίες | Βλάβες |\nΚαταμέτρηση\n013307\nΤΣΙΜΠΟΥΚΗΣ ΑΘΑΝΑΣΙΟΣΧΡΗΣΤΟΣ\n25ΗΣ ΜΑΡΤΙΟΥ 25\n412 21 ΛΑΡΙΣΑ\n10\nΚωδικός ηλεκτρονικής πληρωμής\nRF53907738000300005250337\n������������������������\n000000083,00  6\nΕκκαθαριστικός\nλογαριασμός\nΤιμολόγιο:\n myHome Enter N\nΔιεύθυνση ακινήτου:\n25ΗΣ ΜΑΡΤΙΟΥ 25\n412 21 ΛΑΡΙΣΑ\nΕπόμενη καταμέτρηση:\n21/02/2023\nΑριθμός παροχής\n4 40611581-01 1\nΧρεώσεις προμήθειας ΔΕΗ\n145 , 44€\nΡυθμιζόμενες χρεώσεις\n71 , 29€\nΈναντι Κατανάλωσης\n- 171 , 23€\nΔιάφορα - Δήμος - ΕΡΤ\n34 , 59€\nΦΠΑ\n2 , 91€\nΠροηγούμενο Ανεξόφλητο Ποσό\nΑγνοήστε το εάν έχει πληρωθεί\nΣυνολικό ποσό πληρωμής\n*83 , 00€\nΠΟΣΟ ΠΛΗΡΩΜΗΣ\n*83,00€\nΕΞΟΦΛΗΣΗ ΕΩΣ\n17/11/2022\nΗ κατανάλωσή σας\nΚατανάλωση Ηλεκτρικής Ενέργειας 1.387 kWh\nΠερίοδος Κατανάλωσης\n25/06/2022     -     24/10/2022\nΗμέρες\n122\nΗμ/νία Έκδοσης\n26/10/2022\nΑ/Α Λογαριασμού\n1310962402\nΣελίδα 1 από 2\n  299-2022\nEL-00013307\nΚλείστε τώρα ραντεβού, εύκολα & γρήγορα, σε ένα από τα επιλεγμένα καταστήματα, με ένα κλικ στο dei.gr\nΈχετε ενεργοποιήσει Σύμβαση για το προϊόν\nMyHomeEnter.\nΗ Σύμβαση λήγει 29/12/2022.\nΣας ενημερώνουμε για τη δυνατότητα ένταξης στο Κοινωνικό Οικιακό\nΤιμολόγιο (ΚΟΤ) μέσω της ιστοσελίδας της ΗΔΙΚΑ Α.Ε. (www.idika.gr).\nΥπενθυμίζουμε ότι το Τιμολόγιο Πολυτέκνων κατaργήθηκε και η\nσυγκεκριμένη κατηγορία εντάσσεται ...

# %%
#PyPDF2 doenst work!
for file in pdf_files[0:1]:
    f = open(file,'rb')

    # List of every page's text.
    # The index will correspond to the page number.
    pdf_text = []

    pdf_reader = PyPDF2.PdfReader(f)

    for p in range(len(pdf_reader.pages)):
        
        single_page = pdf_reader.pages[p]

        pdf_text.append(single_page.extract_text())
